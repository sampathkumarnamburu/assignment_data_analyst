# %%
# Libraries to help with reading and manipulating data
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline

# %%
df = pd.read_csv(r'C:\Users\saikrishna\Downloads\zomato dataset\zomato.csv', encoding='latin-1')

# %%
final_df.head()
# Out:
#    Restaurant ID                        Restaurant Name  Country Code  City  \
# 0        3400025                             Jahanpanah             1  Agra
# 1        3400341                    Rangrezz Restaurant             1  Agra
# 2        3400005                Time2Eat - Mama Chicken             1  Agra
# 3        3400021  Chokho Jeeman Marwari Jain Bhojanalya             1  Agra
# 4        3400017                         Pinch Of Spice             1  Agra
#
#                                              Address     Locality  \
# 0  E 23, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 1  E-20, Shopping Arcade, Sadar Bazaar, Agra Cant...   Agra Cantt
# 2        Main Market, Sadar Bazaar, Agra Cantt, Agra   Agra Cantt
# 3  1/48, Delhi Gate, Station Road, Raja Mandi, Ci...  Civil Lines
# 4  23/453, Opposite Sanjay Cinema, Wazipura Road,...  Civil Lines
#
#     Locality Verbose  Longitude   Latitude                        Cuisines  \
# ...

# %%
df_country = pd.read_excel(r'C:\Users\saikrishna\Downloads\zomato dataset\Country-Code.xlsx')

# %%
final_df.tail()
# Out:
#       Restaurant ID                           Restaurant Name  Country Code  \
# 9546       17697389                       The Screaming Eagle           216
# 9547       17697424                             The Thai Bowl           216
# 9548       17697332                Tokyo Japanese Steak House           216
# 9549       17694056  Theo Yianni's Authentic Greek Restaurant           216
# 9550       17559793                 Fishpatrick's Crabby Cafe           216
#
#                 City                                      Address  \
# 9546        Waterloo            228 E 4th St., Waterloo, IA 50703
# 9547        Waterloo      624 Sycamore Street, Waterloo, IA 50703
# 9548        Waterloo        1931 Sears Street, Waterloo, IA 50702
# 9549         Weirton          322 American Way, Weirton, WV 26062
# 9550  Winchester Bay  196 Bayfront Loop, Winchester Bay, OR 97467
#
#             Locality                Locality Verbose   Longitude   Latitude  \
# ...

# %%
final_df= pd.merge(df,df_country,on= 'Country Code',how='right')

# %%
final_df.shape
# Out:
# (9551, 22)

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
final_df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes', 'Country'],
#       dtype='object')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
final_df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
final_df.describe(include='int64')
# Out:
#        Restaurant ID  Country Code  Average Cost for two  Price range  \
# count   9.551000e+03   9551.000000           9551.000000  9551.000000
# mean    9.051128e+06     18.365616           1199.210763     1.804837
# std     8.791521e+06     56.750546          16121.183073     0.905609
# min     5.300000e+01      1.000000              0.000000     1.000000
# 25%     3.019625e+05      1.000000            250.000000     1.000000
# 50%     6.004089e+06      1.000000            400.000000     2.000000
# 75%     1.835229e+07      1.000000            700.000000     2.000000
# max     1.850065e+07    216.000000         800000.000000     4.000000
#
#               Votes
# count   9551.000000
# mean     156.909748
# std      430.169145
# min        0.000000
# 25%        5.000000
# 50%       31.000000
# 75%      131.000000
# max    10934.000000

# %%
sns.boxplot(data=final_df, x='Price range');

# %%
sns.boxplot(data=final_df, x='Votes')
# Out:
# <Axes: xlabel='Votes'>

# %%
final_df.describe(exclude='object')
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
final_df.describe(include='float64')
# Out:
#          Longitude     Latitude  Aggregate rating
# count  9551.000000  9551.000000       9551.000000
# mean     64.126574    25.854381          2.666370
# std      41.467058    11.007935          1.516378
# min    -157.948486   -41.330428          0.000000
# 25%      77.081343    28.478713          2.500000
# 50%      77.191964    28.570469          3.200000
# 75%      77.282006    28.642758          3.700000
# max     174.832089    55.976980          4.900000

# %%
final_df.describe(include='object')
# Out:
#         Restaurant Name       City           Address         Locality  \
# count              9551       9551              9551             9551
# unique             7446        141              8918             1208
# top     Cafe Coffee Day  New Delhi  Sector 41, Noida  Connaught Place
# freq                 83       5473                11              122
#
#                   Locality Verbose      Cuisines            Currency  \
# count                         9551          9542                9551
# unique                        1265          1825                  12
# top     Connaught Place, New Delhi  North Indian  Indian Rupees(Rs.)
# freq                           122           936                8652
#
#        Has Table booking Has Online delivery Is delivering now  \
# count               9551                9551              9551
# unique                 2                   2                 2
# top                   No                  No                No
# ...

# %%
[null_value for null_value in df.columns if df[null_value].isnull().sum()>1]
# Out:
# ['Cuisines']

# %%
country_names = final_df.Country.value_counts().index

# %%
country_val= final_df.Country.value_counts().values

# %%
plt.pie(country_val[:3],labels= country_names[:3],autopct="%1.2f%%")
plt.show()

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %%
sns.barplot(final_df,x='Votes',y='Rating text',hue='Rating color')
# Out:
# <Axes: xlabel='Votes', ylabel='Rating text'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(final_df,x='Aggregate rating')
# Out:
# <Axes: xlabel='Aggregate rating', ylabel='count'>

# %% [markdown]
# Most of the restaurants have 0.0 rating and the highest rating is 4.9 with about 61 restaurants and average rating is 3.1-3.2 with 1041 restaurants.

# %%
fig = plt.subplots(figsize=(7,5))
sns.boxplot(final_df,x='Price range', y='Aggregate rating')
# Out:
# <Axes: xlabel='Price range', ylabel='Aggregate rating'>

# %% [markdown]
# In the boxplot all the plots are Right skewed and we couldn't possibly explain the data so let's try this with histogram plot.

# %%
sns.histplot(data=final_df, x='Aggregate rating',kde = True);

# %%
sns.pairplot(final_df)
# Out:
# C:\Users\saikrishna\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10,7))
sns.countplot(data=final_df, x='Country')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(final_df , x = 'City' , y = 'Votes');
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %%
final_df.hist(figsize=(10,15))
plt.show()

# %%
zomato_corr = df[['Country Code','Votes','Latitude','Longitude']]
sns.heatmap(zomato_corr.corr(),linewidth=1.0)
plt.show()

# %%
final_df['Cuisines'].value_counts().head(15)
# Out:
# Cuisines
# North Indian                      936
# North Indian, Chinese             511
# Fast Food                         354
# Chinese                           354
# North Indian, Mughlai             334
# Cafe                              299
# Bakery                            218
# North Indian, Mughlai, Chinese    197
# Bakery, Desserts                  170
# Street Food                       149
# Pizza, Fast Food                  131
# Chinese, Fast Food                118
# Mithai, Street Food               116
# South Indian                      112
# Bakery, Fast Food                 108
# Name: count, dtype: int64
